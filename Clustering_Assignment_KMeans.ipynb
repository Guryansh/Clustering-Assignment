# %% [markdown]
# <a href="https://colab.research.google.com/github/Guryansh/Clustering-Assignment/blob/main/Clustering_Assignment_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
facebookDataSet = get_data("facebook")[:1000]
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys
# 0          1         1           0
# 1          0         0           0
# 2          1         0           0
# 3          0         0           0
# 4          0         0           0

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(facebookDataSet, verbose=False)

# %%
result = [[[] for _ in range(3)] for _ in range(6)]
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[0][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3b3d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3b3d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e3b3d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e3b3d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e3b3d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e3b3d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e3b3d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3b3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3b3d_row0_col0" class="data row0 col0" >-0.0001</td>
#       <td id="T_e3b3d_row0_col1" class="data row0 col1" >1.0018</td>
#       <td id="T_e3b3d_row0_col2" class="data row0 col2" >0.9980</td>
#       <td id="T_e3b3d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e3b3d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e3b3d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_5f9eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f9eb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5f9eb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5f9eb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5f9eb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5f9eb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5f9eb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f9eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f9eb_row0_col0" class="data row0 col0" >-0.0002</td>
#       <td id="T_5f9eb_row0_col1" class="data row0 col1" >1.0021</td>
#       <td id="T_5f9eb_row0_col2" class="data row0 col2" >0.9979</td>
#       <td id="T_5f9eb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5f9eb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5f9eb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_dfaaf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfaaf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dfaaf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dfaaf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dfaaf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dfaaf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dfaaf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfaaf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfaaf_row0_col0" class="data row0 col0" >-0.0003</td>
#       <td id="T_dfaaf_row0_col1" class="data row0 col1" >1.0019</td>
#       <td id="T_dfaaf_row0_col2" class="data row0 col2" >0.9979</td>
#       <td id="T_dfaaf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dfaaf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dfaaf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [[], [], []], [[], [], []], [[], [], []], [[], [], []], [[], [], []]]

# %%
#NORMALIZATION
kMeanClusteringParameters = setup(facebookDataSet,  normalize = True, normalize_method = 'zscore', verbose=False)
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[1][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a565" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a565_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7a565_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7a565_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7a565_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7a565_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7a565_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a565_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a565_row0_col0" class="data row0 col0" >0.0010</td>
#       <td id="T_7a565_row0_col1" class="data row0 col1" >1.7244</td>
#       <td id="T_7a565_row0_col2" class="data row0 col2" >19.5856</td>
#       <td id="T_7a565_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7a565_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7a565_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_78bcf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78bcf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_78bcf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_78bcf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_78bcf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_78bcf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_78bcf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78bcf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78bcf_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_78bcf_row0_col1" class="data row0 col1" >1.6204</td>
#       <td id="T_78bcf_row0_col2" class="data row0 col2" >15.0509</td>
#       <td id="T_78bcf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_78bcf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_78bcf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_8bb17" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bb17_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8bb17_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8bb17_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8bb17_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8bb17_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8bb17_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bb17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bb17_row0_col0" class="data row0 col0" >0.0005</td>
#       <td id="T_8bb17_row0_col1" class="data row0 col1" >1.4887</td>
#       <td id="T_8bb17_row0_col2" class="data row0 col2" >14.5480</td>
#       <td id="T_8bb17_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8bb17_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8bb17_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [(0.001, 1.7244, 19.5856), (0.0007, 1.6204, 15.0509), (0.0005, 1.4887, 14.548)], [[], [], []], [[], [], []], [[], [], []], [[], [], []]]

# %%
#TRANSFORMATION
kMeanClusteringParameters = setup(facebookDataSet,  transformation = True, transformation_method = 'yeo-johnson', verbose=False)
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[2][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0bd4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0bd4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c0bd4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c0bd4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c0bd4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c0bd4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c0bd4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0bd4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0bd4_row0_col0" class="data row0 col0" >0.3357</td>
#       <td id="T_c0bd4_row0_col1" class="data row0 col1" >889.1587</td>
#       <td id="T_c0bd4_row0_col2" class="data row0 col2" >0.9875</td>
#       <td id="T_c0bd4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c0bd4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c0bd4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_131c8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_131c8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_131c8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_131c8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_131c8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_131c8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_131c8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_131c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_131c8_row0_col0" class="data row0 col0" >0.2883</td>
#       <td id="T_131c8_row0_col1" class="data row0 col1" >783.4277</td>
#       <td id="T_131c8_row0_col2" class="data row0 col2" >1.1072</td>
#       <td id="T_131c8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_131c8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_131c8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_dd4e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd4e6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dd4e6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dd4e6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dd4e6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dd4e6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dd4e6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd4e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd4e6_row0_col0" class="data row0 col0" >0.3324</td>
#       <td id="T_dd4e6_row0_col1" class="data row0 col1" >770.9377</td>
#       <td id="T_dd4e6_row0_col2" class="data row0 col2" >0.9379</td>
#       <td id="T_dd4e6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dd4e6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dd4e6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [(0.001, 1.7244, 19.5856), (0.0007, 1.6204, 15.0509), (0.0005, 1.4887, 14.548)], [(0.3357, 889.1587, 0.9875), (0.2883, 783.4277, 1.1072), (0.3324, 770.9377, 0.9379)], [[], [], []], [[], [], []], [[], [], []]]

# %%
#PCA
kMeanClusteringParameters = setup(facebookDataSet,  pca = True, pca_method = 'linear', verbose=False)
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[3][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_389a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_389a2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_389a2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_389a2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_389a2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_389a2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_389a2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_389a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_389a2_row0_col0" class="data row0 col0" >0.9468</td>
#       <td id="T_389a2_row0_col1" class="data row0 col1" >3833.2647</td>
#       <td id="T_389a2_row0_col2" class="data row0 col2" >0.1269</td>
#       <td id="T_389a2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_389a2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_389a2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_82c86" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82c86_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_82c86_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_82c86_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_82c86_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_82c86_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_82c86_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82c86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82c86_row0_col0" class="data row0 col0" >0.8356</td>
#       <td id="T_82c86_row0_col1" class="data row0 col1" >3710.6286</td>
#       <td id="T_82c86_row0_col2" class="data row0 col2" >0.4905</td>
#       <td id="T_82c86_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_82c86_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_82c86_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a399d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a399d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a399d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a399d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a399d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a399d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a399d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a399d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a399d_row0_col0" class="data row0 col0" >0.5887</td>
#       <td id="T_a399d_row0_col1" class="data row0 col1" >4541.2600</td>
#       <td id="T_a399d_row0_col2" class="data row0 col2" >0.6406</td>
#       <td id="T_a399d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a399d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a399d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [(0.001, 1.7244, 19.5856), (0.0007, 1.6204, 15.0509), (0.0005, 1.4887, 14.548)], [(0.3357, 889.1587, 0.9875), (0.2883, 783.4277, 1.1072), (0.3324, 770.9377, 0.9379)], [(0.9468, 3833.2647, 0.1269), (0.8356, 3710.6286, 0.4905), (0.5887, 4541.26, 0.6406)], [[], [], []], [[], [], []]]

# %%
#T+N
kMeanClusteringParameters = setup(facebookDataSet,  transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[4][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7cfa9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cfa9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7cfa9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7cfa9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7cfa9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7cfa9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7cfa9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cfa9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cfa9_row0_col0" class="data row0 col0" >0.0018</td>
#       <td id="T_7cfa9_row0_col1" class="data row0 col1" >1.7604</td>
#       <td id="T_7cfa9_row0_col2" class="data row0 col2" >15.3103</td>
#       <td id="T_7cfa9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7cfa9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7cfa9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_df492" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df492_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_df492_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_df492_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_df492_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_df492_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_df492_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df492_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df492_row0_col0" class="data row0 col0" >0.0018</td>
#       <td id="T_df492_row0_col1" class="data row0 col1" >1.6402</td>
#       <td id="T_df492_row0_col2" class="data row0 col2" >14.0086</td>
#       <td id="T_df492_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_df492_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_df492_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_e361c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e361c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e361c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e361c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e361c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e361c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e361c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e361c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e361c_row0_col0" class="data row0 col0" >0.0007</td>
#       <td id="T_e361c_row0_col1" class="data row0 col1" >1.6337</td>
#       <td id="T_e361c_row0_col2" class="data row0 col2" >16.0781</td>
#       <td id="T_e361c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e361c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e361c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [(0.001, 1.7244, 19.5856), (0.0007, 1.6204, 15.0509), (0.0005, 1.4887, 14.548)], [(0.3357, 889.1587, 0.9875), (0.2883, 783.4277, 1.1072), (0.3324, 770.9377, 0.9379)], [(0.9468, 3833.2647, 0.1269), (0.8356, 3710.6286, 0.4905), (0.5887, 4541.26, 0.6406)], [(0.0018, 1.7604, 15.3103), (0.0018, 1.6402, 14.0086), (0.0007, 1.6337, 16.0781)], [[], [], []]]

# %%
#T+N+PCA
kMeanClusteringParameters = setup(facebookDataSet, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)
for i in range(3,6):
  KMeanClusteringModel = create_model('kmeans', num_clusters=i)
  model_results = pull()
  silhouette_score = model_results['Silhouette'][0]
  calinski_harabasz_score = model_results['Calinski-Harabasz'][0]
  davies_bouldin_score = model_results['Davies-Bouldin'][0]
  result[5][i-3]=(silhouette_score,calinski_harabasz_score,davies_bouldin_score)
print(result)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89158" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89158_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_89158_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_89158_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_89158_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_89158_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_89158_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89158_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89158_row0_col0" class="data row0 col0" >-0.0004</td>
#       <td id="T_89158_row0_col1" class="data row0 col1" >1.8525</td>
#       <td id="T_89158_row0_col2" class="data row0 col2" >19.5309</td>
#       <td id="T_89158_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_89158_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_89158_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_733ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_733ed_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_733ed_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_733ed_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_733ed_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_733ed_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_733ed_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_733ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_733ed_row0_col0" class="data row0 col0" >-0.0003</td>
#       <td id="T_733ed_row0_col1" class="data row0 col1" >1.7998</td>
#       <td id="T_733ed_row0_col2" class="data row0 col2" >16.9694</td>
#       <td id="T_733ed_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_733ed_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_733ed_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_fd71d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd71d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fd71d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fd71d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fd71d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fd71d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fd71d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd71d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd71d_row0_col0" class="data row0 col0" >-0.0006</td>
#       <td id="T_fd71d_row0_col1" class="data row0 col1" >1.5183</td>
#       <td id="T_fd71d_row0_col2" class="data row0 col2" >16.4865</td>
#       <td id="T_fd71d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fd71d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fd71d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# [[(-0.0001, 1.0018, 0.998), (-0.0002, 1.0021, 0.9979), (-0.0003, 1.0019, 0.9979)], [(0.001, 1.7244, 19.5856), (0.0007, 1.6204, 15.0509), (0.0005, 1.4887, 14.548)], [(0.3357, 889.1587, 0.9875), (0.2883, 783.4277, 1.1072), (0.3324, 770.9377, 0.9379)], [(0.9468, 3833.2647, 0.1269), (0.8356, 3710.6286, 0.4905), (0.5887, 4541.26, 0.6406)], [(0.0018, 1.7604, 15.3103), (0.0018, 1.6402, 14.0086), (0.0007, 1.6337, 16.0781)], [(-0.0004, 1.8525, 19.5309), (-0.0003, 1.7998, 16.9694), (-0.0006, 1.5183, 16.4865)]]

# %%
import pandas as pd
import matplotlib.pyplot as plt

columns = ['Silhouette', 'Calinski-Harabasz', 'Davies-Bouldin']

rows = ['c = 3', 'c = 4', 'c = 5']

headers = ['', 'No Processing', 'Normalization', 'Transformation', 'PCA', 'T+N', 'T+N+PCA']

dfs = []

df_nothing = pd.DataFrame(result[0], index=rows, columns=columns)
dfs.append(df_nothing.T)

df_normalization = pd.DataFrame(result[1], index=rows, columns=columns)
dfs.append(df_normalization.T)

df_transformation = pd.DataFrame(result[2], index=rows, columns=columns)
dfs.append(df_transformation.T)

df_pca = pd.DataFrame(result[3], index=rows, columns=columns)
dfs.append(df_pca.T)

df_tn = pd.DataFrame(result[4], index=rows, columns=columns)
dfs.append(df_tn.T)

df_tnpca = pd.DataFrame(result[5], index=rows, columns=columns)
dfs.append(df_tnpca.T)

combined_df = pd.concat(dfs, axis=1, keys=headers[1:])

# %%
fig, axs = plt.subplots(2, 1, figsize=(32, 4), gridspec_kw={'height_ratios': [1, 8]})

# Headers Table
axs[0].axis('off')
headers_table = axs[0].table(cellText=[[header for header in headers[1:]]],
                             cellLoc='center',
                             loc='center',
                             bbox=[0.15, 0, 0.8, 1],
                             colWidths=[.4, .395, .475, .5, .415, .4])
headers_table.auto_set_font_size(False)
headers_table.set_fontsize(12)
for _, cell in headers_table.get_celld().items():
    cell.set_linewidth(0.5)

column_widths = [0.15] * len(combined_df.columns)  # Adjust this as per your requirements

# Main Table
axs[1].axis('off')
main_table = axs[1].table(cellText=combined_df.values,
                          rowLabels=combined_df.index,
                          colLabels=[f'{col[1]}' for col in combined_df.columns],
                          loc='center',
                          cellLoc='center',
                          bbox=[0.1, 0, 0.8, 1],
                          colWidths=column_widths)
main_table.auto_set_font_size(False)
main_table.set_fontsize(10)
for i, col in enumerate(combined_df.columns):
    column_width = max(len(str(item)) for item in combined_df[col]) + 2
    main_table.auto_set_column_width([i])

fig.tight_layout(pad=1.5)
plt.subplots_adjust(hspace=0.1)
plt.title('Using KMeans Clustering', fontsize=16, ha='center', va='center', y=1.3)
plt.savefig('combined_df_table_with_headers.png', bbox_inches='tight', dpi=300)
plt.show()
